# %% [markdown]
# <a href="https://www.kaggle.com/code/luckysingh3003/bagofword-tfidf?scriptVersionId=308275800" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %%
import numpy as np
import pandas as pd

# %%
df=pd.DataFrame({'text':['people watch me',' me watch me','people write comment','me write comment'],'output':[1,1,0,0]})

# %%
df
# Out:
#                    text  output
# 0       people watch me       1
# 1           me watch me       1
# 2  people write comment       0
# 3      me write comment       0

# %%
from sklearn.feature_extraction.text import CountVectorizer

# %%
cv=CountVectorizer(ngram_range=(2,2))

# %%
bow=cv.fit_transform(df['text'])

# %%
print(cv.vocabulary_)
# Out:
# {'people watch': 2, 'watch me': 4, 'me watch': 0, 'people write': 3, 'write comment': 5, 'me write': 1}

# %%
print(bow[0].toarray())
print(bow[1].toarray())
# Out:
# [[0 0 1 0 1 0]]
# [[1 0 0 0 1 0]]

# %%
cv.transform(["me watch and write comment of me"]).toarray()
# Out:
# array([[1, 0, 0, 0, 0, 1]])

# %% [markdown]
# #### class sklearn.feature_extraction.text.CountVectorizer(*, input='content', encoding='utf-8', decode_error='strict', strip_accents=None, lowercase=True, preprocessor=None, tokenizer=None, stop_words=None, token_pattern='(?u)\\b\\w\\w+\\b', ngram_range=(1, 1), analyzer='word', max_df=1.0, min_df=1, max_features=None, vocabulary=None, binary=False, dtype=<class 'numpy.int64'>)[source]

# %%
### binary=True then all non-zero count =1.  jaha bhi 2 ya 3 or or bds number uss ko 1 bna dega.. iss me ham freq nhi ptakrte iss me pta lrte hai ke exist krta hauke nhi

# %% [markdown]
# ### binary=True then all non-zero count =1.  jaha bhi 2 ya 3 or or bda number uss ko 1 bna dega.. iss me ham freq nhi pta krte iss me pta krte hai ke exist krta hai ke nhi

# %%
###

# %% [markdown]
# ### **max_features=1 then is ka matlab hai ke ek hi featiure output me chayea jis ke frequency sb se jada hai or baki ignore ho jai ge words

# %% [markdown]
# ### TFIDF

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
tfidf=TfidfVectorizer()
tfidf.fit_transform(df['text']).toarray()
# Out:
# array([[0.        , 0.49681612, 0.61366674, 0.61366674, 0.        ],
#        [0.        , 0.8508161 , 0.        , 0.52546357, 0.        ],
#        [0.57735027, 0.        , 0.57735027, 0.        , 0.57735027],
#        [0.61366674, 0.49681612, 0.        , 0.        , 0.61366674]])
